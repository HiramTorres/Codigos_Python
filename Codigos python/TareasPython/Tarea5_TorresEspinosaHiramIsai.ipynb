# %% [markdown]
# ## Función : $\frac{2 - e^{-x} + x^2}{3}$

# %%
 from math import *
def g(x):
    x=(2-e**(-x) +x**2)/3
    return x
p0=1
tol=0.00001
N_ite=100
p=10
i=1
while i<=N_ite:
    p=g(p0)
    if abs(p-p0)<=tol:
        print("El punto fijo es ",p," despues de ",i," iteraciones")
        break
    i=i+1
    p0=p
if i>=n0:
    print("El metodo no converge ")
# Out:
# El punto fijo es  0.6089976910334355  despues de  21  iteraciones

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-5,5,0.1)
y = (2-e**-x +x**2)/3
zeros = np.zeros(len(x))
plt.plot(x,y,'g',x,zeros, '--r')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Función : $\frac{5}{x^{2}}+2$

# %%
from math import *
def g(x):
    x=5/x**2 + 2
    return x
p0=1
tol=0.00001
N_ite=50
p=4
i=1
while i<=N_ite:
    p=g(p0)
    if abs(p-p0)<=tol:
        print("El punto fijo es ",p," despues de ",i," iteraciones")
        break
    i=i+1
    p0=p
if i>=n0:
    print("El metodo no converge ")
# Out:
# El punto fijo es  2.6906497584230067  despues de  21  iteraciones

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-.5,.5,0.1)
y = 5/x**2 + 2
zeros = np.zeros(len(x))
plt.plot(x,y,'g',x,zeros, '--r')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Función : $0.5(sin(x) - cos(x))$

# %%
from math import *
import numpy as np
def g(x):
    x=(0.5 *(math.sin(x) - math.cos(x)))
    return x
p0=1
tol=0.00001
N_ite=50
p=10
i=1
while i<=N_ite:
    p=g(p0)
    if abs(p-p0)<=tol:
        print("El punto fijo es ",p," despues de ",i," iteraciones")
        break
    i=i+1
    p0=p
if i>=n0:
    print("El metodo no converge ")
# Out:
# El punto fijo es  -0.7048119673198092  despues de  8  iteraciones

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-10,10,0.1)
y = 0.5*(np.sin(x) - np.cos(x))
zeros = np.zeros(len(x))
plt.plot(x,y,'g',x,zeros, '-.r')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
